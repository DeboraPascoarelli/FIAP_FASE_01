# %% [markdown]
# # Importanto arquivos de várias fontes
#
# * Json
# * Txt
# * Xlsx
# * Html

# %%
import pandas as pd

# %% [markdown]
# # Json

# %%
json =  open(r"C:\Users\fabia\OneDrive\FIAP_INICIO\WarnUp_materiais\Python Pandas_Materiais\extras\extras\dados\aluguel.json")
print(json.read())
# Out:
# [{"Tipo":"Quitinete","Bairro":"Copacabana","Quartos":1,"Vagas":0,"Suites":0,"Area":40,"Valor":1700.0,"Condominio":500.0,"IPTU":60.0},
# {"Tipo":"Casa","Bairro":"Jardim Bot\u00e2nico","Quartos":2,"Vagas":0,"Suites":1,"Area":100,"Valor":7000.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Conjunto Comercial\/Sala","Bairro":"Barra da Tijuca","Quartos":0,"Vagas":4,"Suites":0,"Area":150,"Valor":5200.0,"Condominio":4020.0,"IPTU":1111.0},
# {"Tipo":"Apartamento","Bairro":"Centro","Quartos":1,"Vagas":0,"Suites":0,"Area":15,"Valor":800.0,"Condominio":390.0,"IPTU":20.0},
# {"Tipo":"Apartamento","Bairro":"Higien\u00f3polis","Quartos":1,"Vagas":0,"Suites":0,"Area":48,"Valor":800.0,"Condominio":230.0,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Vista Alegre","Quartos":3,"Vagas":1,"Suites":0,"Area":70,"Valor":1200.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Cachambi","Quartos":2,"Vagas":0,"Suites":0,"Area":50,"Valor":1300.0,"Condominio":301.0,"IPTU":17.0},
# ...

# %%
df_json = pd.read_json(r"C:\Users\fabia\OneDrive\FIAP_INICIO\WarnUp_materiais\Python Pandas_Materiais\extras\extras\dados\aluguel.json")

# %%
df_json
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %% [markdown]
# # TXT

# %%
txt = open(r"C:\Users\fabia\OneDrive\FIAP_INICIO\WarnUp_materiais\Python Pandas_Materiais\extras\extras\dados\aluguel.txt")
print(txt.read)
# Out:
# <built-in method read of _io.TextIOWrapper object at 0x0000022121D036B0>

# %%
df_txt = pd.read_table(r"C:\Users\fabia\OneDrive\FIAP_INICIO\WarnUp_materiais\Python Pandas_Materiais\extras\extras\dados\aluguel.txt")
df_txt
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %% [markdown]
# # Excel

# %%
df_xlsx = pd.read_excel(r"C:\Users\fabia\OneDrive\FIAP_INICIO\WarnUp_materiais\Python Pandas_Materiais\extras\extras\dados\aluguel.xlsx")
df_xlsx
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %% [markdown]
# # HTML

# %% [markdown]
# Temos duas páginas que servirão de exemplo para demonstrar a próxima funcionalidade do Jupyter. A primeira página possui uma tabela de preços de planos ativos para comercialização. Coletamos os dados dessa tabela, e criamos um arquivo html. Para acessar este arquivo, escreveremos:

# %%
df_html = pd.read_html(r"C:\Users\fabia\OneDrive\FIAP_INICIO\WarnUp_materiais\Python Pandas_Materiais\extras\extras\dados\dados_html_1.html")
df_html[0]
# Out:
#   FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
# 0      00 A 18               R$218,99           R$192,60    R$334,48
# 1      19 A 23               R$263,63           R$207,67    R$380,06
# 2      24 A 28               R$322,44           R$224,26    R$464,39
# 3      29 A 33               R$402,05           R$258,63    R$566,68
# 4      34 A 38               R$455,17           R$306,37    R$664,61
# 5      39 A 43               R$489,29           R$417,93    R$742,72
# 6      44 A 48               R$582,65           R$495,24    R$869,47
# 7      49 A 53               R$718,86           R$562,64  R$1.046,29
# 8      54 A 58               R$908,54           R$721,00  R$1.355,74
# 9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53

# %%
#Podemos, inclusive, simplesmente passar a URL para exibirmos os dados da tabela:

df_html = pd.read_html(r'https://unafiscosaude.org.br/site/tabelas-de-precos-dos-planos-ativos-para-comercializacao/')
df_html[0]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 #Podemos, inclusive, simplesmente passar a URL para exibirmos os dados da tabela:
# ----> 3 df_html = pd.read_html(r'https://unafiscosaude.org.br/site/tabelas-de-precos-dos-planos-ativos-para-comercializacao/')
#       4 df_html[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\html.py:1246, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1230 if isinstance(io, str) and not any(
#    1231     [
#    1232         is_file_like(io),
#    (...)
#    1236     ]
#    1237 ):
#    1238     warnings.warn(
# ...

# %%
df_html = pd.read_html('https://www.federalreserve.gov//releases//h3//current//default.htm')

len(df_html)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df_html = pd.read_html('https://www.federalreserve.gov//releases//h3//current//default.htm')
#       3 len(df_html)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\html.py:1246, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only, extract_links, dtype_backend, storage_options)
#    1230 if isinstance(io, str) and not any(
#    1231     [
#    1232         is_file_like(io),
#    (...)
#    1236     ]
#    1237 ):
#    1238     warnings.warn(
#    1239         "Passing literal html to 'read_html' is deprecated and "
#    1240         "will be removed in a future version. To read from a "
# ...

# %% [markdown]
# Teremos como saída o número 3. Quer dizer que a lista possui três dataframes, isto é, as três tabelas. Podemos acessá-las individualmente escrevendo df_html[0], df_html[1] e df_html[2].
#
# O Pandas possui outras maneiras de acessar dataframes e conteúdos de outras fontes da dados, mas estas são as mais importantes.
