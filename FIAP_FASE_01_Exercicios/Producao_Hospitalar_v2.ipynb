# %% [markdown]
# ## F01-Análise Exploratória dos Dados - A01
#
# ### Aquisição e Leitura de Dados Reais

# %% [markdown]
# ### Analisando Dados de Produção Hospitalar

# %%
# Importando Bibliotecas
import pandas as pd
import numpy as np

# Libs Gráficas

import plotly.express as px
import seaborn as sns
import matplotlib.pyplot as plt

# Avisos

import warnings
warnings.filterwarnings('ignore')

# %%
# Abrindo o arquivo CSV
dados = pd.read_csv(r"C:\Users\fabia\OneDrive\FIAP\Materiais\FASE 1_materiais\A150850189_28_143_208(a).csv", encoding="ISO-8859-1", skiprows=3, sep=";", skipfooter=12,thousands=".", decimal="," )

# %% [markdown]
# <span style="font-size:small; color:pink;"> No código acima, tratei todo o CSV e por fim transformei todo o código em uma variável (= dados). Toda vez que eu quiser trazer o meu DataFrame, basta digitar 'dados' na linha de comando, pois todo o código foi encapsulado dentro dele.

# %%
dados
# Out:
#       Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 0              11 Rondônia         -         -         -         -         -
# 1                  12 Acre         -         -         -         -         -
# 2              13 Amazonas         -         -         -         -         -
# 3               14 Roraima         -         -         -         -         -
# 4                  15 Pará         -         -         -         -         -
# 5                 16 Amapá         -         -         -         -         -
# 6             17 Tocantins         -         -         -         -         -
# 7              21 Maranhão         -         -         -         -         -
# 8                 22 Piauí         -         -         -         -         -
# 9                 23 Ceará         -         -         -         -         -
# 10  24 Rio Grande do Norte         -         -         -         -         -
# ...

# %%
# trazendo somente 5 linhas do DataFrame / Se não colocarmos nenhum número dentro do () ele traz por default 5 linhas
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2021/Jan     2021/Fev     2021/Mar  \
# 0        -        -        -  ...  10045624.39  10677245.18  18147121.02
# 1        -        -        -  ...   4175526.06   5282655.42   5699597.78
# 2        -        -        -  ...  27406458.57  22341042.63  27923786.94
# 3        -        -        -  ...   3557821.99   4172285.82   5427226.70
# 4        -        -        -  ...  39042349.46  37113440.70  49625416.13
#
# ...

# %%
# trazendo as últimas 5 linhas
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...      2021/Jan      2021/Fev  \
# 22        -        -        -        -  ...  1.159919e+08  1.267303e+08
# 23        -        -        -        -  ...  2.472700e+07  2.560076e+07
# 24        -        -        -        -  ...  1.888971e+07  2.154459e+07
# 25        -        -        -        -  ...  4.263870e+07  4.571547e+07
# 26        -        -        -        -  ...  2.448472e+07  2.415606e+07
#
#         2021/Mar      2021/Abr      2021/Mai      2021/Jun      2021/Jul  \
# ...

# %%
# Trazendo a média somente das colunas que possuem números
dados.mean(numeric_only=True)
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2021/Mai    8.727186e+07
# 2021/Jun    7.759041e+07
# 2021/Jul    6.084629e+07
# 2021/Ago    4.388572e+07
# Total       6.852321e+09
# Length: 170, dtype: float64

# %%
# informações do DataFrame / Float = números e Object = String
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 293 entries, Unidade da Federação to Total
# dtypes: float64(170), object(123)
# memory usage: 61.9+ KB

# %%
# Formatando os números / .f é ponto flutuante / .2f = 2 casas decimais
pd.options.display.float_format="{:.2f}".format

# %%
dados.mean(numeric_only=True)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
dados['2008/Ago'].mean(numeric_only=True)
# Out:
# 26645398.35703704

# %% [markdown]
# #### Desafio 1: Fazer o mesmo trabalho acima para o arquivo de Processamento (CSV)
# <span style="font-size:small; color:pink;"> Para fazer isso, basta trocar o caminho do arquivo que está no início do código
# ###### <span style="color:green;"> Testando texto em verde

# %% [markdown]
# #### Desafio 2: Trazer a coluna mais recente

# %%
# Obtendo todas as colunas do DataFrame, exceto a coluna de String (1) e a coluna de Total
colunas_ano_mes = dados.columns[1:-1]

# Selecionando a coluna mais recente de ano/mes
coluna_mais_recente = dados[colunas_ano_mes[-1]]

# Obtendo o nome da coluna mais recente (cabeçalho)
nome_coluna_mais_recente = coluna_mais_recente.name

# Obtendo a primeira linha da coluna mais recentes 
primeira_linha_coluna_mais_recente = coluna_mais_recente.iloc[0]

# Exibindo o cabeçalho da coluna mais recente e seus valores
print(nome_coluna_mais_recente)
print(coluna_mais_recente)
# Out:
# 2021/Set
# 0       1682801.60
# 1                -
# 2       5292323.36
# 3       1496814.75
# 4       4620263.03
# 5        626751.41
# 6        312354.68
# 7      11194657.20
# 8       9371428.06
# 9      16234603.93
# 10      6055806.12
# 11      8962429.99
# 12     35603376.46
# 13      5714532.94
# 14      1509495.66
# 15     24858284.14
# 16     60010941.33
# 17     11916897.69
# 18     43133058.07
# 19    130535317.64
# 20     32660877.10
# 21     18486461.58
# 22     25200345.68
# 23      2445267.12
# 24      7325067.61
# 25     18860370.17
# 26     13173812.37
# Name: 2021/Set, dtype: object

# %% [markdown]
# ## F01-Análise Exploratória dos Dados - A02
# ### Primeiras Visualizações de Dados

# %%
# Toda a tabela é chamada de DataFrame / 1 coluna é chamada de 1 série de Valores e um índice, ou seja, quando pensamos em uma sequencia de valores
# trazendo uma coluna/ série específica

dados["2008/Ago"] # uma única coluna é chamda de 1 Series /
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42502172.22
# 19   180097396.03
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21070201.36
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
# Média do mês de Agosto/2008
dados["2008/Ago"].mean()
# Out:
# 26645398.35703704

# %% [markdown]
# ### Colocando valor inteiro no Gráfico

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# Plotando os dados = exibir os dados em um gráfico
axis = dados.plot(x="Unidade da Federação", y="2008/Ago", figsize=(16,6), kind="bar")
axis.yaxis.set_major_formatter(ticker.StrMethodFormatter('{x:,.2f}')) # traz o valor inteiro no eixo Y / A virgula antes do ponto separa os milhares


# Adicionando rótulo de dados nas barras
for index, value in enumerate(dados["2008/Ago"]):
    axis.text(index,value,str(value), ha="center", va="bottom", rotation=90)  #ha: alinhamento horizontal e va: alinhamento vertical

# Definindo um título para o Gráfico
plt.title(':: Valores de Agosto de 2008 por Undiade da Federação ::')

# Rotacionar os rótulos do eixo x / barras
plt.xticks(rotation=45, ha='right')

# Exibir o gráfico
plt.show() # não retorna textos desnecessários da Biblioteca

# %% [markdown]
# # F01-Análise Exploratória dos Dados - A03
# ## Manipulação de Dados I
# ### Escolhendo mais de uma coluna

# %%
# Quero escolher mais de 1 mês
dados[['2008/Ago','2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %% [markdown]
# ### Excluindo colunas que não possuem dados

# %%
# Quero trabalhar a partir de uma coluna que tenha dados para todas as colunas.
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...    2021/Jan    2021/Fev    2021/Mar  \
# 0        -        -        -  ... 10045624.39 10677245.18 18147121.02
# 1        -        -        -  ...  4175526.06  5282655.42  5699597.78
# 2        -        -        -  ... 27406458.57 22341042.63 27923786.94
# 3        -        -        -  ...  3557821.99  4172285.82  5427226.70
# 4        -        -        -  ... 39042349.46 37113440.70 49625416.13
#
#      2021/Abr    2021/Mai    2021/Jun    2021/Jul    2021/Ago    2021/Set  \
# ...

# %%
# A sacada é buscar a média, pois vai trazer somente as colunas quando temos todos os dados
dados.mean(numeric_only=True)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
# Pego os dados da média e transformo em uma lista / Peguei os índices que são os nomes destas colunas e transformei em uma lista
dados.mean(numeric_only=True).index.tolist()
# Out:
# ['2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
# ...

# %%
# As colunas acima passam a ser as colunas usáveis, ou seja, as colunas que eu quero trabalhar
colunas_usaveis = dados.mean(numeric_only=True).index.tolist()

# Vou pegar essas colunas usáveis e inserir na posição 0 a Unidade da Federação
colunas_usaveis.insert(0,"Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
# Agora vou trazer somente os 5 primeiros elementos 
colunas_usaveis[:5]
# Out:
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
# Retorno dos dados usáveis
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2020/Dez  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ...  9469279.43
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  3820865.83
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 21911210.94
# 3   808448.39   771687.83   876091.18   896952.53  ...  3193708.89
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 37925512.28
#
#      2021/Jan    2021/Fev    2021/Mar    2021/Abr    2021/Mai    2021/Jun  \
# ...

# %% [markdown]
# ### Retirando o índice Automático

# %%
# Quero que a Unidade da Federeção seja o meu índice, e não o índice automático
dados_usaveis = dados_usaveis.set_index('Unidade da Federação')

dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    8909111.89
# 12 Acre        2981072.98
# 13 Amazonas   16493719.52
# 14 Roraima     3181321.82
# 15 Pará       36462011.47
# Name: 2019/Ago, dtype: float64

# %% [markdown]
# ### Localizando um elemento pelo índice / linha

# %%
# Colchete puro é a busca pela coluna / .loc é a busca linha
dados_usaveis.loc['12 Acre']
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %%
# iloc -- Busca pelo número do índice original e não pela palavra do índice setado
dados_usaveis.iloc[1]
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2021/Mai     4326882.24
# 2021/Jun     3458187.11
# 2021/Jul     2302711.01
# 2021/Ago     1196754.85
# Total      475290315.34
# Name: 12 Acre, Length: 170, dtype: float64

# %% [markdown]
# ### Plotanto os Dados

# %%
dados_usaveis.plot(figsize=(15,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %% [markdown]
# ### Trocando os Eixos do Gráfico de Lugar

# %%
# Veja os dados transposto na matriz
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
# Passei os meses para o Eixo x e os Estador para o Eixo Y
dados_usaveis.T.plot(figsize=(15,6))
# Out:
# <Axes: >

# %% [markdown]
# ### Retirando o Total (do gráfico)

# %%
# O total deixa o gráfico desproporcional, pois ele é maior do que o valor de todos os estados
# axis = 0 dropa linhas / axis = 1 dropa coluna
dados_usaveis.drop('Total', axis=1)
dados_usaveis = dados_usaveis.drop('Total', axis=1) # --> isso é os dados usáveis sem a coluna do Total
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %% [markdown]
# ### Refazendo o gráfico sem a coluna de Total

# %%
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
dados_usaveis.T.plot(figsize=(16,5))
# Out:
# <Axes: >

# %% [markdown]
# ### Função Max - Trazendo o maior valor

# %%
dados_usaveis.T.max()
# Out:
# Unidade da Federação
# 11 Rondônia                18147121.02
# 12 Acre                     5699597.78
# 13 Amazonas                27923786.94
# 14 Roraima                  5427226.70
# 15 Pará                    52558327.29
# 16 Amapá                    5672086.52
# 17 Tocantins               10161783.68
# 21 Maranhão                55324683.42
# 22 Piauí                   32550777.47
# 23 Ceará                  102825954.51
# 24 Rio Grande do Norte     41819897.10
# 25 Paraíba                 39602463.80
# 26 Pernambuco             132095684.99
# 27 Alagoas                 30875169.00
# 28 Sergipe                 19720608.49
# 29 Bahia                  134229720.19
# 31 Minas Gerais           275151838.35
# 32 Espírito Santo          58031849.50
# 33 Rio de Janeiro         252175779.88
# 35 São Paulo             1049827695.26
# 41 Paraná                 191861617.22
# 42 Santa Catarina         101661537.37
# 43 Rio Grande do Sul      169687680.33
# ...

# %% [markdown]
# ### Desafio
#
# * Reposicionar a legenda. Dentro? Fora? Onde?
# * Retocar título da visualização do Gráfico
# * Colocar Títulos nos 2 eixos

# %% [markdown]
# ### Reposicionar a legenda. Dentro? Fora? Onde?

# %%
# Reposicionando a legenda do Gráfico / Parte inferior centro e abaixo do eixo x

dados_usaveis.T.plot(figsize = (15,6))
plt.legend(loc='upper center', bbox_to_anchor=(0.5,-0.2), ncol=3)

# %% [markdown]
# ### Retocar título da visualização do Gráfico

# %%
dados_usaveis.T.plot(figsize = (15,6))
plt.legend(loc='upper center', bbox_to_anchor=(0.5,-0.2), ncol=3)
plt.title('Unidades Federativas', fontweight='bold', color='orange')
# Out:
# Text(0.5, 1.0, 'Unidades Federativas')

# %% [markdown]
# ### Colocar Títulos nos 2 eixos

# %%
dados_usaveis.T.plot(figsize = (15,6))
plt.legend(loc='upper center', bbox_to_anchor=(0.5,-0.2), ncol=3)
plt.title('Unidades Federativas', fontweight='bold', color='orange')

# Label 
plt.xlabel('Ano', fontsize = 14)
plt.ylabel('Valor por Unidade Federativa', fontsize = 14)
# Out:
# Text(0, 0.5, 'Valor por Unidade Federativa')

# %% [markdown]
# ### Colocando Valor inteiro no Gráfico

# %%
dados_usaveis.T.plot(figsize = (15,6))

plt.legend(loc='upper center', bbox_to_anchor=(0.5,-0.2), ncol=3)
plt.title('Unidades Federativas', fontweight='bold', color='orange')

# Label 
plt.xlabel('Ano', fontsize = 14)
plt.ylabel('Valor por Unidade Federativa', fontsize = 14)

# Definindo valores inteiros no eixo y
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: f'{int(x)}'))

# %% [markdown]
# ## Manipulação de Dados II
# ### Pegando somente os nomes das colunas

# %%
# Para relembrarmos a tabela
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
# Transpondo a tabela acima
dados_usaveis.T
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37   10470.07     35752.72     4785.91
# 2007/Set                 16397.03   14001.71     45570.64    11858.63
# 2007/Out                133645.19   86200.85    416012.30    43852.67
# 2007/Nov                346912.84  301323.68   2020381.79   369328.51
# 2007/Dez                711758.31  769612.36   5949408.99   470676.43
# ...                           ...        ...          ...         ...
# 2021/Abr              17753851.45 5002272.59  24515920.09  4192540.54
# 2021/Mai              17659855.79 4326882.24  23973537.71  3681417.80
# 2021/Jun              14435903.47 3458187.11  22175398.40  3475205.55
# 2021/Jul              11834435.10 2302711.01  21614943.55  3320807.96
# 2021/Ago               7371334.84 1196754.85  13806958.66  2907871.07
#
# Unidade da Federação     15 Pará   16 Amapá  17 Tocantins  21 Maranhão  \
# ...

# %%
# Pegando somente os nomes das colunas / T.colums vou transpor a tabela acima. Assim consigo pegar os nomes das Unidades de Federação
dados_usaveis.T.columns
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará',
#        '16 Amapá', '17 Tocantins', '21 Maranhão', '22 Piauí', '23 Ceará',
#        '24 Rio Grande do Norte', '25 Paraíba', '26 Pernambuco', '27 Alagoas',
#        '28 Sergipe', '29 Bahia', '31 Minas Gerais', '32 Espírito Santo',
#        '33 Rio de Janeiro', '35 São Paulo', '41 Paraná', '42 Santa Catarina',
#        '43 Rio Grande do Sul', '50 Mato Grosso do Sul', '51 Mato Grosso',
#        '52 Goiás', '53 Distrito Federal'],
#       dtype='object', name='Unidade da Federação')

# %% [markdown]
# ### Selecionando apenas algumas colunas

# %%
# Vou selecionar apenas os 5 primeiras elementos das colunas da tabela acima (transposta), ou seja, apenas os 5 primeiros Estados
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:5]
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
dados_usaveis[:5].T
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37   10470.07     35752.72     4785.91
# 2007/Set                 16397.03   14001.71     45570.64    11858.63
# 2007/Out                133645.19   86200.85    416012.30    43852.67
# 2007/Nov                346912.84  301323.68   2020381.79   369328.51
# 2007/Dez                711758.31  769612.36   5949408.99   470676.43
# ...                           ...        ...          ...         ...
# 2021/Abr              17753851.45 5002272.59  24515920.09  4192540.54
# 2021/Mai              17659855.79 4326882.24  23973537.71  3681417.80
# 2021/Jun              14435903.47 3458187.11  22175398.40  3475205.55
# 2021/Jul              11834435.10 2302711.01  21614943.55  3320807.96
# 2021/Ago               7371334.84 1196754.85  13806958.66  2907871.07
#
# Unidade da Federação     15 Pará
# 2007/Ago               181159.29
# 2007/Set               433414.74
# ...

# %% [markdown]
# ### Plotando os 7 primeiros elementos

# %%
# # # Cabeçalho da tabela é legenda, a primeira coluna da tabela é x e o miolo da tabela é y
dados_usaveis[:7].T.plot(figsize=(15,6))
# Out:
# <Axes: >

# %% [markdown]
# ### Aleatoridade Fixa
# Qualquer pessoa que utilizar esse método aleatório, terão os mesmos resultados / números

# %%
import numpy as np

# %%
np.random.seed(524387)
dados_usaveis.sample(n=7)

# Qualquer pessoa que pegar esse código, terá o mesmo resultado abaixo
# Out:
#                       2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez  \
# Unidade da Federação
# 17 Tocantins           4113.76   76633.06   343702.61  1068685.94  3022200.87
# 26 Pernambuco        400640.85 1088340.42  2973553.48  6699828.82 16919031.39
# 31 Minas Gerais      971394.37 2861781.50 10018011.35 21730281.63 43429517.54
# 22 Piauí             220788.25  353468.67  1078182.68  2406035.32  4929772.93
# 25 Paraíba            97352.78  368130.43  1002088.64  2149873.40  5448177.36
# 29 Bahia             135146.36  448349.75  1382038.11  3348779.62 11948984.56
# 42 Santa Catarina    693955.05 1092964.12  3562300.82  7578502.38 14772555.10
#
#                          2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 17 Tocantins           5136474.61  5051932.07  5200151.87  5343714.73
# 26 Pernambuco         51279301.86 26222079.10 30716361.81 30589332.79
# 31 Minas Gerais      206493861.30 70301089.50 79119005.51 79046322.41
# ...

# %% [markdown]
# ### Plotando os dados aleatórios

# %%
dados_dos_7_estados = dados_usaveis.sample(n=7)
dados_dos_7_estados.T.plot(figsize=(15,6)) # não será os mesmos resultados que o código acima / Não serão os mesmos 7 números
# Out:
# <Axes: >

# %% [markdown]
# ### Adicionando a Coluna de Total
# Neste caso vou criar a uma coluna Total

# %%
# sum() --> Soma ao longo das colunas / sum(axis = 1) --> Soma ao longo das linhas
# eixo das colunas = ao longo das linhas
# eixo das linhas = ao longo das colunas
dados_usaveis['Total'] = dados_usaveis.sum(axis=1)
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %% [markdown]
# ### Desafio
# * Ordernar o nosso DataFrame para que na primeira linha tenha a linha com o maior gasto, e na última linha com o menor gasto (ordenação)
# * Adicionar uma coluna com a Região de cada Estado
# * Adicione o seu Estado nesta lista de 7 estados

# %% [markdown]
# #### Ordenar DataFrame do Maior para o Menor

# %%
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
ordenados_por_total = dados_usaveis.sort_values(by='Total', ascending=False)
ordenados_por_total= ordenados_por_total.drop('Total', axis=1)
ordenados_por_total.head(5)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1049827695.26 173062308.33 170621304.31
# 31 Minas Gerais      43429517.54  206493861.30  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  252175779.88  44128159.73  42907909.35
#
# ...

# %% [markdown]
# #### Adicionar uma coluna com a Região de cada Estado

# %%
# Abrindo o arquivo CSV das regiões
df_regioes = pd.read_csv(r"C:\Users\fabia\OneDrive\FIAP_INICIO\FASE 1\estados_regioes.csv", encoding="utf-8", sep=';')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[55], line 2
#       1 # Abrindo o arquivo CSV das regiões
# ----> 2 df_regioes = pd.read_csv(r"C:\Users\fabia\OneDrive\FIAP_INICIO\FASE 1\estados_regioes.csv", encoding="utf-8", sep=';')
#
# ...

# %%
df_regioes.head()
# Out:
#   Unidade da Federação    Região
# 0              12 Acre     Norte
# 1           27 Alagoas   Sudeste
# 2             16 Amapá  Nordeste
# 3          13 Amazonas  Nordeste
# 4             29 Bahia  Nordeste

# %% [markdown]
# ##### Join Tables / Merge de arquivos CSV

# %%
# Join Tables - Unidades das Federações e Regiões
df_com_regioes = pd.merge(df_regioes, dados, on='Unidade da Federação')
df_com_regioes
# Out:
#       Unidade da Federação        Região  1992/Mar  1992/Abr  1993/Mai  \
# 0                  12 Acre         Norte         -         -         -
# 1               27 Alagoas       Sudeste         -         -         -
# 2                 16 Amapá      Nordeste         -         -         -
# 3              13 Amazonas      Nordeste         -         -         -
# 4                 29 Bahia      Nordeste         -         -         -
# 5                 23 Ceará  Centro-Oeste         -         -         -
# 6      53 Distrito Federal      Nordeste         -         -         -
# 7        32 Espírito Santo      Nordeste         -         -         -
# 8                 52 Goiás       Sudeste         -         -         -
# 9              21 Maranhão  Centro-Oeste         -         -         -
# 10          51 Mato Grosso           Sul         -         -         -
# 11   50 Mato Grosso do Sul         Norte         -         -         -
# ...

# %%
# Excluindo colunas que não possuem dados
df_com_regioes.mean(numeric_only=True)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
df_com_regioes.mean(numeric_only=True).index.tolist()
# Out:
# ['2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
# ...

# %%
df_com_regioes.head()
# Out:
#   Unidade da Federação    Região 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 0              12 Acre     Norte        -        -        -        -        -
# 1           27 Alagoas   Sudeste        -        -        -        -        -
# 2             16 Amapá  Nordeste        -        -        -        -        -
# 3          13 Amazonas  Nordeste        -        -        -        -        -
# 4             29 Bahia  Nordeste        -        -        -        -        -
#
#   1994/Fev 1994/Mai 1994/Ago  ...    2021/Jan    2021/Fev     2021/Mar  \
# 0        -        -        -  ...  4175526.06  5282655.42   5699597.78
# 1        -        -        -  ... 20154290.67 21539842.43  30875169.00
# 2        -        -        -  ...  2786277.13  2664375.13   3960131.30
# 3        -        -        -  ... 27406458.57 22341042.63  27923786.94
# 4        -        -        -  ... 88213804.44 96878079.79 117816174.41
#
# ...

# %%
df_com_regioes.head()
# Out:
#   Unidade da Federação    Região 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 0              12 Acre     Norte        -        -        -        -        -
# 1           27 Alagoas   Sudeste        -        -        -        -        -
# 2             16 Amapá  Nordeste        -        -        -        -        -
# 3          13 Amazonas  Nordeste        -        -        -        -        -
# 4             29 Bahia  Nordeste        -        -        -        -        -
#
#   1994/Fev 1994/Mai 1994/Ago  ...    2021/Jan    2021/Fev     2021/Mar  \
# 0        -        -        -  ...  4175526.06  5282655.42   5699597.78
# 1        -        -        -  ... 20154290.67 21539842.43  30875169.00
# 2        -        -        -  ...  2786277.13  2664375.13   3960131.30
# 3        -        -        -  ... 27406458.57 22341042.63  27923786.94
# 4        -        -        -  ... 88213804.44 96878079.79 117816174.41
#
# ...

# %%
# A sacada é buscar a média, pois vai trazer somente as colunas quando temos todos os dados
df_com_regioes.mean(numeric_only=True)
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2021/Mai     87271862.20
# 2021/Jun     77590406.47
# 2021/Jul     60846287.01
# 2021/Ago     43885716.30
# Total      6852320913.49
# Length: 170, dtype: float64

# %%
# Pego os dados da média e transformo em uma lista / Peguei os índices que são os nomes destas colunas e transformei em uma lista
df_com_regioes.mean(numeric_only=True).index.tolist()
# Out:
# ['2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
# ...

# %% [markdown]
# #### Inserindo as colunas dos Estados e Regiões

# %%
# As colunas acima passam a ser as colunas usáveis (apenas do Mês), ou seja, as colunas que eu quero trabalhar
colunas_usaveis_M = df_com_regioes.mean(numeric_only=True).index.tolist()

# Precisei transformar a lista acima em Tuple, porque se não, ao tentar inserir as colunas 'Unidade da Federação' e 'Região' 
# e chamar o DataFrame dá erro, alegando que 'Redgião' não é índice.
colunas_usaveis_M = tuple(colunas_usaveis_M)

# %%
# Agora eu preciso embutir as colunas ''Unidade da Federação'e 'Região' na Tupla


colunas_usaveis = ['Unidade da Federação','Região'] + [coluna for coluna in df_com_regioes.columns if coluna.startswith(colunas_usaveis_M) ]

dados_usaveis_R = df_com_regioes[colunas_usaveis]
dados_usaveis_R.head(6)
# Out:
#   Unidade da Federação        Região  2007/Ago  2007/Set   2007/Out  \
# 0              12 Acre         Norte  10470.07  14001.71   86200.85
# 1           27 Alagoas       Sudeste 104243.75 174024.90  595544.54
# 2             16 Amapá      Nordeste  33672.74 104822.98  118378.28
# 3          13 Amazonas      Nordeste  35752.72  45570.64  416012.30
# 4             29 Bahia      Nordeste 135146.36 448349.75 1382038.11
# 5             23 Ceará  Centro-Oeste 357904.65 572356.18 1865065.71
#
#     2007/Nov    2007/Dez    2008/Jan    2008/Fev    2008/Mar  ...    2020/Dez  \
# 0  301323.68   769612.36  1731744.62  1743978.66  2057439.02  ...  3820865.83
# 1 1125396.73  2564966.65 16623799.85  8112220.30  9210505.56  ... 18566269.71
# 2  226661.18   844019.90  1329876.61  1275063.72  1177745.93  ...  2841469.69
# 3 2020381.79  5949408.99 11419210.08  7934652.10  8641517.13  ... 21911210.94
# 4 3348779.62 11948984.56 74456787.96 33410124.06 41329594.35  ... 87649577.75
# ...

# %%
# Retirando o índice automático
# Quero que a Unidade da Federeção seja o meu índice, e não o índice automático
dados_usaveis_R = dados_usaveis_R.set_index('Unidade da Federação')

dados_usaveis_R.head()
# Out:
#                         Região  2007/Ago  2007/Set   2007/Out   2007/Nov  \
# Unidade da Federação
# 12 Acre                  Norte  10470.07  14001.71   86200.85  301323.68
# 27 Alagoas             Sudeste 104243.75 174024.90  595544.54 1125396.73
# 16 Amapá              Nordeste  33672.74 104822.98  118378.28  226661.18
# 13 Amazonas           Nordeste  35752.72  45570.64  416012.30 2020381.79
# 29 Bahia              Nordeste 135146.36 448349.75 1382038.11 3348779.62
#
#                         2007/Dez    2008/Jan    2008/Fev    2008/Mar  \
# Unidade da Federação
# 12 Acre                769612.36  1731744.62  1743978.66  2057439.02
# 27 Alagoas            2564966.65 16623799.85  8112220.30  9210505.56
# 16 Amapá               844019.90  1329876.61  1275063.72  1177745.93
# 13 Amazonas           5949408.99 11419210.08  7934652.10  8641517.13
# 29 Bahia             11948984.56 74456787.96 33410124.06 41329594.35
#
# ...

# %%
dados_usaveis_R.drop('Região', axis=1)
dados_usaveis_R = dados_usaveis_R.drop('Região', axis=1) # --> isso é os dados usáveis R sem a coluna da Região
dados_usaveis_R.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 27 Alagoas           104243.75 174024.90  595544.54 1125396.73  2564966.65
# 16 Amapá              33672.74 104822.98  118378.28  226661.18   844019.90
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 29 Bahia             135146.36 448349.75 1382038.11 3348779.62 11948984.56
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 27 Alagoas           16623799.85  8112220.30  9210505.56 10466691.94
# 16 Amapá              1329876.61  1275063.72  1177745.93  1396371.51
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 29 Bahia             74456787.96 33410124.06 41329594.35 42826993.62
#
# ...

# %%
# Plotando os Dados
dados_usaveis_R.T.plot(figsize=(15,6))
# Out:
# <Axes: >

# %%
# Função Max
dados_usaveis_R.T.max()
# Out:
# Unidade da Federação
# 12 Acre                    475290315.34
# 27 Alagoas                2394793268.76
# 16 Amapá                   337181964.14
# 13 Amazonas               2061943006.93
# 29 Bahia                 10498497979.38
# 23 Ceará                  7118540187.61
# 53 Distrito Federal       2778456616.77
# 32 Espírito Santo         3710941856.86
# 52 Goiás                  5380179246.60
# 21 Maranhão               4161325769.23
# 51 Mato Grosso            2386584382.72
# 50 Mato Grosso do Sul     2516383489.01
# 31 Minas Gerais          21899546392.60
# 15 Pará                   4968811817.17
# 25 Paraíba                2796673182.96
# 41 Paraná                15672157558.11
# 26 Pernambuco             9243658123.01
# 22 Piauí                  2450508593.82
# 33 Rio de Janeiro        11131868548.73
# 24 Rio Grande do Norte    2867428082.03
# 43 Rio Grande do Sul     13613341350.00
# 11 Rondônia               1088059702.25
# 14 Roraima                 352546288.71
# ...

# %%
# Pegando somente os nomes das colunas da Séries acima

# Para relembrarmos a tabela
dados_usaveis_R.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 27 Alagoas           104243.75 174024.90  595544.54 1125396.73  2564966.65
# 16 Amapá              33672.74 104822.98  118378.28  226661.18   844019.90
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 29 Bahia             135146.36 448349.75 1382038.11 3348779.62 11948984.56
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 27 Alagoas           16623799.85  8112220.30  9210505.56 10466691.94
# 16 Amapá              1329876.61  1275063.72  1177745.93  1396371.51
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 29 Bahia             74456787.96 33410124.06 41329594.35 42826993.62
#
# ...

# %%
# Transpondo a tabela acima
dados_usaveis_R.T
# Out:
# Unidade da Federação      12 Acre    27 Alagoas     16 Amapá   13 Amazonas  \
# 2007/Ago                 10470.07     104243.75     33672.74      35752.72
# 2007/Set                 14001.71     174024.90    104822.98      45570.64
# 2007/Out                 86200.85     595544.54    118378.28     416012.30
# 2007/Nov                301323.68    1125396.73    226661.18    2020381.79
# 2007/Dez                769612.36    2564966.65    844019.90    5949408.99
# ...                           ...           ...          ...           ...
# 2021/Mai               4326882.24   30550686.94   5672086.52   23973537.71
# 2021/Jun               3458187.11   26888254.59   5469150.38   22175398.40
# 2021/Jul               2302711.01   17475906.50   4136950.62   21614943.55
# 2021/Ago               1196754.85   11393875.70   1875241.91   13806958.66
# Total                475290315.34 2394793268.76 337181964.14 2061943006.93
#
# ...

# %%
# Pegando somente os nomes das colunas / T.colums vou transpor o DF. Assim consigo pegar os nomes das Unidades de Federação

dados_usaveis_R.T.columns
# Out:
# Index(['12 Acre', '27 Alagoas', '16 Amapá', '13 Amazonas', '29 Bahia',
#        '23 Ceará', '53 Distrito Federal', '32 Espírito Santo', '52 Goiás',
#        '21 Maranhão', '51 Mato Grosso', '50 Mato Grosso do Sul',
#        '31 Minas Gerais', '15 Pará', '25 Paraíba', '41 Paraná',
#        '26 Pernambuco', '22 Piauí', '33 Rio de Janeiro',
#        '24 Rio Grande do Norte', '43 Rio Grande do Sul', '11 Rondônia',
#        '14 Roraima', '42 Santa Catarina', '35 São Paulo', '28 Sergipe',
#        '17 Tocantins'],
#       dtype='object', name='Unidade da Federação')

# %%
# Selecionando apenas algumas colunas
# Vou selecionar apenas os 5 primeiras elementos das colunas da tabela acima (transposta), ou seja, apenas os 5 primeiros Estados

dados_usaveis_R.T.columns[:5]
# Out:
# Index(['12 Acre', '27 Alagoas', '16 Amapá', '13 Amazonas', '29 Bahia'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis_R[:5].T
# Out:
# Unidade da Federação      12 Acre    27 Alagoas     16 Amapá   13 Amazonas  \
# 2007/Ago                 10470.07     104243.75     33672.74      35752.72
# 2007/Set                 14001.71     174024.90    104822.98      45570.64
# 2007/Out                 86200.85     595544.54    118378.28     416012.30
# 2007/Nov                301323.68    1125396.73    226661.18    2020381.79
# 2007/Dez                769612.36    2564966.65    844019.90    5949408.99
# ...                           ...           ...          ...           ...
# 2021/Mai               4326882.24   30550686.94   5672086.52   23973537.71
# 2021/Jun               3458187.11   26888254.59   5469150.38   22175398.40
# 2021/Jul               2302711.01   17475906.50   4136950.62   21614943.55
# 2021/Ago               1196754.85   11393875.70   1875241.91   13806958.66
# Total                475290315.34 2394793268.76 337181964.14 2061943006.93
#
# Unidade da Federação       29 Bahia
# ...

# %%
# Plotando os 7 Primeiros Elementos

# Cabeçalho da tabela é legenda, a primeira coluna da tabela é x e o miolo da tabela é y
dados_usaveis_R[:7].T.plot(figsize=(15,6))
# Out:
# <Axes: >

# %% [markdown]
# #### Voltando a coluna Total

# %%
# sum() --> Soma ao longo das colunas / sum(axis = 1) --> Soma ao longo das linhas
# eixo das colunas = ao longo das linhas
# eixo das linhas = ao longo das colunas
dados_usaveis_R['Total'] = dados_usaveis.sum(axis=1)
dados_usaveis_R.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 27 Alagoas           104243.75 174024.90  595544.54 1125396.73  2564966.65
# 16 Amapá              33672.74 104822.98  118378.28  226661.18   844019.90
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 29 Bahia             135146.36 448349.75 1382038.11 3348779.62 11948984.56
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 27 Alagoas           16623799.85  8112220.30  9210505.56 10466691.94
# 16 Amapá              1329876.61  1275063.72  1177745.93  1396371.51
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 29 Bahia             74456787.96 33410124.06 41329594.35 42826993.62
#
# ...

# %% [markdown]
# #### Ordernar o DF_R com o valor Total do Maior para o menor

# %%
# Ordenando o DF acima
ordenados_por_total_R = dados_usaveis_R.sort_values(by='Total', ascending=False)
ordenados_por_total_R = ordenados_por_total_R.drop('Total', axis=1)
ordenados_por_total_R.head(5)
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1049827695.26 173062308.33 170621304.31
# 31 Minas Gerais      43429517.54  206493861.30  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  252175779.88  44128159.73  42907909.35
#
# ...

# %%
# Plotando o DF acima
ordenados_por_total_R.head(5).T.plot(figsize=(15,6))
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulação de Dados III
# ### Ordendo o Data Frame do maior para o menor (Total)

# %%
# Relembrando o DataFrame
dados_usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
# Ordenando do maior para o menor (Total)
ordenados_por_total = dados_usaveis.sort_values(by='Total', ascending=False)
ordenados_por_total = ordenados_por_total.drop('Total',axis=1)
ordenados_por_total.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1049827695.26 173062308.33 170621304.31
# 31 Minas Gerais      43429517.54  206493861.30  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  252175779.88  44128159.73  42907909.35
#
# ...

# %%
#  Atenção: Por mais que o df acima esteja com o head para os cinco primeiros dados, tem que colocar novamente quando for plotar 
ordenados_por_total.head(5).T.plot(figsize=(15,6))
# Out:
# <Axes: >

# %% [markdown]
# #### ******Adicionando São Paulo aos 7 Estados

# %%
dados_dos_7_estados = ordenados_por_total.sample(7,replace=True)
dados_dos_7_estados
# Out:
#                       2007/Ago   2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 26 Pernambuco        400640.85 1088340.42 2973553.48 6699828.82 16919031.39
# 29 Bahia             135146.36  448349.75 1382038.11 3348779.62 11948984.56
# 14 Roraima             4785.91   11858.63   43852.67  369328.51   470676.43
# 27 Alagoas           104243.75  174024.90  595544.54 1125396.73  2564966.65
# 29 Bahia             135146.36  448349.75 1382038.11 3348779.62 11948984.56
# 12 Acre               10470.07   14001.71   86200.85  301323.68   769612.36
# 28 Sergipe            27453.63   78565.19  122952.94  775705.52  2765495.63
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 26 Pernambuco        51279301.86 26222079.10 30716361.81 30589332.79
# 29 Bahia             74456787.96 33410124.06 41329594.35 42826993.62
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# ...

# %%
# Adicionando São Paulo a lista dos 7 Estados

dados_dos_7_estados.loc['35 São Paulo'] = ordenados_por_total.loc['35 São Paulo'].values
dados_dos_7_estados
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 26 Pernambuco         400640.85 1088340.42  2973553.48  6699828.82
# 29 Bahia              135146.36  448349.75  1382038.11  3348779.62
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 27 Alagoas            104243.75  174024.90   595544.54  1125396.73
# 29 Bahia              135146.36  448349.75  1382038.11  3348779.62
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 28 Sergipe             27453.63   78565.19   122952.94   775705.52
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 26 Pernambuco        16919031.39   51279301.86  26222079.10  30716361.81
# 29 Bahia             11948984.56   74456787.96  33410124.06  41329594.35
# 14 Roraima             470676.43     808448.39    771687.83    876091.18
# ...

# %%
# Plotando os 8 estados acima
dados_dos_7_estados.T.plot(figsize=(15,6))
# Out:
# <Axes: >

# %% [markdown]
# ### Como incluir dados em um DataFrame

# %%
cinco_estados = dados_usaveis_R.head()
cinco_estados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, 12 Acre to 29 Bahia
# Columns: 170 entries, 2007/Ago to Total
# dtypes: float64(170)
# memory usage: 6.7+ KB

# %%
SP = dados_usaveis_R.loc['35 São Paulo']
SP.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 170 entries, 2007/Ago to Total
# Series name: 35 São Paulo
# Non-Null Count  Dtype
# --------------  -----
# 170 non-null    float64
# dtypes: float64(1)
# memory usage: 6.7+ KB

# %%
cinco_estados.loc['35 São Paulo'] = SP.values

# %%
cinco_estados
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 27 Alagoas            104243.75  174024.90   595544.54  1125396.73
# 16 Amapá               33672.74  104822.98   118378.28   226661.18
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 29 Bahia              135146.36  448349.75  1382038.11  3348779.62
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 12 Acre                769612.36    1731744.62   1743978.66   2057439.02
# 27 Alagoas            2564966.65   16623799.85   8112220.30   9210505.56
# 16 Amapá               844019.90    1329876.61   1275063.72   1177745.93
# 13 Amazonas           5949408.99   11419210.08   7934652.10   8641517.13
# 29 Bahia             11948984.56   74456787.96  33410124.06  41329594.35
# ...

# %% [markdown]
# 1) chamei 5 estados do DF dadosdados_usaveis_R / cinco_estados = dados.usaveis.head()
# 2) Depois, criei uma variável chamada SP com a função '.loc' / A função .loc localiza linhas dentro de um DF
# 3) Para acrescentar a linha de SP no DF de 5 estados eu tenho que declarar que quero incluir São Paulo em 'cinco_estados'. Então, pego 'cinco_estados' + .loc + 'São Paulo' = SP + . values
#
# "cinco_estados.loc['35 São Paulo'] = SP.values"
#
# * "A função diz: "Localize a linha, cujo índice é igual a '35 São Paulo' e coloque os seus valores dentro de 'cinco_estados"

# %% [markdown]
# ### Escolhendo colunas

# %%
# Neste caso vou desconsiderar as colunas de 2007 a 
# O .columns devolve as colunas

# Significa que estou escolhendo todas as colunas a partir da sexta coluna [6:] / ou seja, escolhendo as colunas de 2008/Fev para frente.  Para trás seria [:6],
# porém não inclui a coluna de 2008/FEV
ordenados_por_total.columns[6:]
colunas_interessadas = ordenados_por_total.columns[6:]

# Vou sobrescrever o ordenado por total
ordenados_por_total = ordenados_por_total[colunas_interessadas] # O 'antigo' ordenado por total tinha as colunas anteriores a 2008/FEV 

# Aqui retiramos os outliers, que estava de 2008 para trás

# %%
# Plotando os dados / Em 2021 tivemos um pico de gastos com a Saúde e é considerável, uma vez aque em 2021 tivemos a pandemia.
ordenados_por_total.head(5).T.plot(figsize=(15,6))
# Out:
# <Axes: >

# %% [markdown]
# ### Desafio
#
# * Adicionar seu estado no gráfico acima. Se já tiver, escolher um outro
# * Deixar o gráfico mais refinado
# * Pesquisar sobre o sort_index na documentação do Pandas
# * Googlar os casos de Dengue do Brasil e verificar se existe algum padrão com os gastos encontrados aqui
# * Plotar somente uma região do Brasil
